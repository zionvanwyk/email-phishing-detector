# %%
from datasets import Dataset, DatasetDict
from google.colab import drive
import pandas as pd
from huggingface_hub import notebook_login


drive.mount('/content/drive')
notebook_login()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
csv_path = "/content/drive/MyDrive/phishingdata/phishing_email.csv"
df = pd.read_csv(csv_path)
dataset = Dataset.from_pandas(df)

split_dataset = dataset.train_test_split(test_size=0.2, seed=42)

final_dataset = DatasetDict({
    'train': split_dataset['train'],
    'test': split_dataset['test']
})

# %%
repo_name = "zionia/phishing-emails"
final_dataset.push_to_hub(repo_name)

print(f"Dataset successfully uploaded to {repo_name}")
# Out:
# Pushing dataset shards to the dataset hub:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/66 [00:00<?, ?ba/s]
# Pushing dataset shards to the dataset hub:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/17 [00:00<?, ?ba/s]
# Dataset successfully uploaded to zionia/phishing-emails
